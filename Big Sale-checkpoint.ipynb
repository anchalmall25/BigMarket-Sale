# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_train=pd.read_csv(r'C:\Users\hp\Desktop\python file\Bigmart sale\Train.csv')
df_test=pd.read_csv(r'C:\Users\hp\Desktop\python file\Bigmart sale\Test.csv')

# %%
df_train.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
df_train.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
df_test.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                   976
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  1606
# Outlet_Location_Type            0
# Outlet_Type                     0
# dtype: int64

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
df_train.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
df_train['Item_Weight'].describe()
# Out:
# count    7060.000000
# mean       12.857645
# std         4.643456
# min         4.555000
# 25%         8.773750
# 50%        12.600000
# 75%        16.850000
# max        21.350000
# Name: Item_Weight, dtype: float64

# %%
df_train['Item_Weight'].fillna(df_train['Item_Weight'].mean(),inplace=True)
df_test['Item_Weight'].fillna(df_test['Item_Weight'].mean(),inplace=True)

# %%
df_train.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                     0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
df_train['Outlet_Size'].value_counts()
# Out:
# Medium    2793
# Small     2388
# High       932
# Name: Outlet_Size, dtype: int64

# %%
df_train['Outlet_Size'].mode()
# Out:
# 0    Medium
# dtype: object

# %%
df_train['Outlet_Size'].fillna(df_train['Outlet_Size'].mode()[0],inplace=True)
df_test['Outlet_Size'].fillna(df_test['Outlet_Size'].mode()[0],inplace=True)

# %%
df_train
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
df_train.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
df_train.drop(['Item_Identifier','Outlet_Identifier'],axis=1,inplace=True)
df_test.drop(['Item_Identifier','Outlet_Identifier'],axis=1,inplace=True)

# %%
df_train
# Out:
#       Item_Weight Item_Fat_Content  Item_Visibility              Item_Type  \
# 0           9.300          Low Fat         0.016047                  Dairy
# 1           5.920          Regular         0.019278            Soft Drinks
# 2          17.500          Low Fat         0.016760                   Meat
# 3          19.200          Regular         0.000000  Fruits and Vegetables
# 4           8.930          Low Fat         0.000000              Household
# ...           ...              ...              ...                    ...
# 8518        6.865          Low Fat         0.056783            Snack Foods
# 8519        8.380          Regular         0.046982           Baking Goods
# 8520       10.600          Low Fat         0.035186     Health and Hygiene
# 8521        7.210          Regular         0.145221            Snack Foods
# 8522       14.800          Low Fat         0.044878            Soft Drinks
#
# ...

# %%
import dtale
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\dash_bootstrap_components\_table.py:5: UserWarning:
#
#
# The dash_html_components package is deprecated. Please replace
# `import dash_html_components as html` with `from dash import html`

# %%
dtale.show(df_train)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://LAPTOP-2HUU7O9B:40000/dtale/iframe/1"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
from pandas_profiling import ProfileReport

# %%
profile=ProfileReport(df_train, title="Pandas Profile Report")

# %%
profile
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v3.1.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2021-10-19 16:23:28.503759&quot;&gt;&lt;title&gt;Pandas Profile Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
plt.figure(figsize=(10,5))
sns.heatmap(df_train.corr(),annot=True)
plt.show()

# %%
import klib

# %%
klib.cat_plot(df_train)
# Out:
# GridSpec(6, 5)

# %%
klib.corr_plot(df_train)
# Out:
# <AxesSubplot:title={'center':'Feature-correlation (pearson)'}>

# %%
klib.dist_plot(df_train)
# Out:
# <AxesSubplot:xlabel='Item_Outlet_Sales', ylabel='Density'>

# %%
klib.corr_mat(df_train)
# Out:
# <style type="text/css">
# #T_f86cc_row0_col0, #T_f86cc_row0_col2, #T_f86cc_row0_col4, #T_f86cc_row1_col1, #T_f86cc_row2_col0, #T_f86cc_row2_col2, #T_f86cc_row2_col3, #T_f86cc_row2_col4, #T_f86cc_row3_col2, #T_f86cc_row3_col3, #T_f86cc_row4_col0, #T_f86cc_row4_col2, #T_f86cc_row4_col4 {
#   color: None;
# }
# #T_f86cc_row0_col1, #T_f86cc_row0_col3, #T_f86cc_row1_col0, #T_f86cc_row1_col2, #T_f86cc_row1_col3, #T_f86cc_row1_col4, #T_f86cc_row2_col1, #T_f86cc_row3_col0, #T_f86cc_row3_col1, #T_f86cc_row3_col4, #T_f86cc_row4_col1, #T_f86cc_row4_col3 {
#   color: #FF3344;
# }
# </style>
# <table id="T_f86cc_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Item_Weight</th>
#       <th class="col_heading level0 col1" >Item_Visibility</th>
#       <th class="col_heading level0 col2" >Item_MRP</th>
#       <th class="col_heading level0 col3" >Outlet_Establishment_Year</th>
# ...

# %%
klib.missingval_plot(df_train)
# Out:
# No missing values found in the dataset.

# %% [markdown]
# klib.data_cleaning(df) # performs datacleaning (drop duplicates & empty rows/cols, adjust dtypes,...)
# - klib.clean_column_names(df) # cleans and standardizes column names, also called inside data_cleaning()
# - klib.convert_datatypes(df) # converts existing to more efficient dtypes, also called inside data_cleaning()
# - klib.drop_missing(df) # drops missing values, also called in data_cleaning()
# - klib.mv_col_handling(df) # drops features with high ratio of missing vals based on informational content
# - klib.pool_duplicate_subsets(df) # pools subset of cols based on duplicates with min. loss of information

# %%
klib.data_cleaning(df_train)
# Out:
# Shape of cleaned data: (8523, 10)Remaining NAs: 0
#
# Changes:
# Dropped rows: 0
#      of which 0 duplicates. (Rows: [])
# Dropped columns: 0
#      of which 0 single valued.     Columns: []
# Dropped missing values: 0
# Reduced memory by at least: 0.43 MB (-66.15%)
#       item_weight item_fat_content  item_visibility              item_type  \
# 0             9.3          Low Fat         0.016047                  Dairy
# 1            5.92          Regular         0.019278            Soft Drinks
# 2            17.5          Low Fat          0.01676                   Meat
# 3       19.200001          Regular              0.0  Fruits and Vegetables
# 4            8.93          Low Fat              0.0              Household
# ...           ...              ...              ...                    ...
# 8518        6.865          Low Fat         0.056783            Snack Foods
# 8519         8.38          Regular         0.046982           Baking Goods
# ...

# %%
klib.clean_column_names(df_train)
# Out:
#       item_weight item_fat_content  item_visibility              item_type  \
# 0           9.300          Low Fat         0.016047                  Dairy
# 1           5.920          Regular         0.019278            Soft Drinks
# 2          17.500          Low Fat         0.016760                   Meat
# 3          19.200          Regular         0.000000  Fruits and Vegetables
# 4           8.930          Low Fat         0.000000              Household
# ...           ...              ...              ...                    ...
# 8518        6.865          Low Fat         0.056783            Snack Foods
# 8519        8.380          Regular         0.046982           Baking Goods
# 8520       10.600          Low Fat         0.035186     Health and Hygiene
# 8521        7.210          Regular         0.145221            Snack Foods
# 8522       14.800          Low Fat         0.044878            Soft Drinks
#
# ...

# %%
klib.mv_col_handling(df_train)
# Out:
#       item_weight item_fat_content  item_visibility              item_type  \
# 0           9.300          Low Fat         0.016047                  Dairy
# 1           5.920          Regular         0.019278            Soft Drinks
# 2          17.500          Low Fat         0.016760                   Meat
# 3          19.200          Regular         0.000000  Fruits and Vegetables
# 4           8.930          Low Fat         0.000000              Household
# ...           ...              ...              ...                    ...
# 8518        6.865          Low Fat         0.056783            Snack Foods
# 8519        8.380          Regular         0.046982           Baking Goods
# 8520       10.600          Low Fat         0.035186     Health and Hygiene
# 8521        7.210          Regular         0.145221            Snack Foods
# 8522       14.800          Low Fat         0.044878            Soft Drinks
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder           #label encodin
le=LabelEncoder()

# %%
df_train=df_train.apply(le.fit_transform)

# %%
df_train
# Out:
#       item_weight  item_fat_content  item_visibility  item_type  item_mrp  \
# 0             284                 1              664          4      5592
# 1              57                 2              880         14       473
# 2             376                 1              715         10      2901
# 3             393                 2                0          6      4227
# 4             265                 1                0          9       627
# ...           ...               ...              ...        ...       ...
# 8518          125                 1             3912         13      4955
# 8519          233                 2             3278          0      2023
# 8520          299                 1             2302          8      1263
# 8521          149                 2             7175         13      1857
# 8522          347                 1             3108         14      1011
#
#       outlet_establishment_year  outlet_size  outlet_location_type  \
# ...

# %%
#hot encoding

from sklearn.preprocessing import OneHotEncoder
ohe=OneHotEncoder

# %%
df_train=pd.get_dummies(df_train,columns=['item_fat_content','outlet_size','outlet_location_type','outlet_type'])

# %%
df_train
# Out:
#       item_weight  item_visibility  item_type  item_mrp  \
# 0             284              664          4      5592
# 1              57              880         14       473
# 2             376              715         10      2901
# 3             393                0          6      4227
# 4             265                0          9       627
# ...           ...              ...        ...       ...
# 8518          125             3912         13      4955
# 8519          233             3278          0      2023
# 8520          299             2302          8      1263
# 8521          149             7175         13      1857
# 8522          347             3108         14      1011
#
#       outlet_establishment_year  item_outlet_sales  item_fat_content_0  \
# 0                             4               2540                   0
# 1                             8                422                   0
# 2                             4               1639                   0
# ...

# %%
X=df_train.drop('item_outlet_sales',axis=1)
Y=df_train['item_outlet_sales']

# %%
Y
# Out:
# 0       2540
# 1        422
# 2       1639
# 3        670
# 4        865
#         ...
# 8518    2047
# 8519     516
# 8520    1018
# 8521    1466
# 8522     697
# Name: item_outlet_sales, Length: 8523, dtype: int64

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,Y_train,Y_test=train_test_split(X,Y,random_state=101,test_size=0.2)

# %%
Y_train
# Out:
# 3684     144
# 1935    1311
# 5142    1242
# 4978    1426
# 2299    2462
#         ...
# 599     3137
# 5695    1193
# 8006    1684
# 1361    2001
# 1547     746
# Name: item_outlet_sales, Length: 6818, dtype: int64

# %%
Y_test
# Out:
# 8179     801
# 8355    2056
# 3411    1529
# 7089     779
# 6954    1858
#         ...
# 1317    1386
# 4996     808
# 531      356
# 3891    1144
# 6629    1839
# Name: item_outlet_sales, Length: 1705, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

# %%
X_train_std=sc.fit_transform(X_train)

# %%
X_test_std=sc.transform(X_test)

# %%
X_train_std
# Out:
# array([[ 1.00439018,  0.96533577, -0.75847359, ...,  0.73160085,
#         -0.34892775, -0.35759513],
#        [-1.23760194,  0.19186569,  1.60759199, ...,  0.73160085,
#         -0.34892775, -0.35759513],
#        [ 1.01496562,  0.29157407,  0.66116576, ...,  0.73160085,
#         -0.34892775, -0.35759513],
#        ...,
#        [ 0.23238346, -1.19862827,  0.18795264, ...,  0.73160085,
#         -0.34892775, -0.35759513],
#        [-0.09545501,  1.29992208, -1.70489982, ...,  0.73160085,
#         -0.34892775, -0.35759513],
#        [ 0.62367454,  1.53980627,  0.4245592 , ..., -1.36686554,
#          2.8659228 , -0.35759513]])

# %%
X_test_std
# Out:
# array([[ 0.06317651,  0.04042575,  0.18795264, ..., -1.36686554,
#          2.8659228 , -0.35759513],
#        [ 0.86690953, -0.4451833 ,  1.37098543, ...,  0.73160085,
#         -0.34892775, -0.35759513],
#        [-1.15299846,  0.48515019, -1.46829326, ...,  0.73160085,
#         -0.34892775, -0.35759513],
#        ...,
#        [ 0.61309911,  1.08506928,  0.89777232, ..., -1.36686554,
#         -0.34892775, -0.35759513],
#        [ 0.77173062, -1.55115374,  0.4245592 , ..., -1.36686554,
#          2.8659228 , -0.35759513],
#        [-2.33744713, -1.47230485,  0.66116576, ...,  0.73160085,
#         -0.34892775, -0.35759513]])

# %%
from sklearn.linear_model import LinearRegression 
lr=LinearRegression()

# %%
lr.fit(X_train_std,Y_train)
# Out:
# LinearRegression()

# %%
lr.predict(X_test_std)
# Out:
# array([1062.43752746, 1697.93752746, 1079.43752746, ...,  718.43752746,
#        1233.43752746, 1689.43752746])

# %%
Y_pred_lr=lr.predict(X_test_std)

# %%
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %%
print(r2_score(Y_test,Y_pred_lr))
print(mean_absolute_error(Y_test,Y_pred_lr))
print(np.sqrt(mean_squared_error(Y_test,Y_pred_lr)))
# Out:
# 0.6232015440583777
# 446.09823735645614
# 558.5990003717038

# %%
from sklearn.ensemble import RandomForestRegressor
rf=RandomForestRegressor()

# %%
rf.fit(X_train,Y_train)
# Out:
# RandomForestRegressor()

# %%
Y_pred_rf=rf.predict(X_test)

# %%
print(r2_score(Y_test,Y_pred_rf))
print(mean_absolute_error(Y_test,Y_pred_rf))
print(np.sqrt(mean_squared_error(Y_test,Y_pred_rf)))
# Out:
# 0.608446684977362
# 433.4501818181819
# 569.4309252323993

# %%
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.model_selection import GridSearchCV

# define models and parameters
model = RandomForestRegressor()
n_estimators = [10, 100, 1000]
max_depth=range(1,31)
min_samples_leaf=np.linspace(0.1, 1.0)
max_features=["auto", "sqrt", "log2"]
min_samples_split=np.linspace(0.1, 1.0, 10)

# define grid search
grid = dict(n_estimators=n_estimators,max_depth=max_depth)

#cv = RepeatedStratifiedKFold(n_splits=5, n_repeats=3, random_state=101)

grid_search_forest = GridSearchCV(estimator=model, param_grid=grid, n_jobs=-1, 
                           scoring='r2',error_score=0,verbose=2,cv=2)

grid_search_forest.fit(X_train_std, Y_train)

# summarize results
print(f"Best: {grid_search_forest.best_score_:.3f} using {grid_search_forest.best_params_}")
means = grid_search_forest.cv_results_['mean_test_score']
stds = grid_search_forest.cv_results_['std_test_score']
params = grid_search_forest.cv_results_['params']

for mean, stdev, param in zip(means, stds, params):
    print(f"{mean:.3f} ({stdev:.3f}) with: {param}")
# Out:
# Fitting 2 folds for each of 90 candidates, totalling 180 fits
# Best: 0.659 using {'max_depth': 5, 'n_estimators': 1000}
# 0.377 (0.001) with: {'max_depth': 1, 'n_estimators': 10}
# 0.375 (0.006) with: {'max_depth': 1, 'n_estimators': 100}
# 0.373 (0.005) with: {'max_depth': 1, 'n_estimators': 1000}
# 0.540 (0.001) with: {'max_depth': 2, 'n_estimators': 10}
# 0.543 (0.000) with: {'max_depth': 2, 'n_estimators': 100}
# 0.542 (0.000) with: {'max_depth': 2, 'n_estimators': 1000}
# 0.616 (0.004) with: {'max_depth': 3, 'n_estimators': 10}
# 0.617 (0.003) with: {'max_depth': 3, 'n_estimators': 100}
# 0.617 (0.003) with: {'max_depth': 3, 'n_estimators': 1000}
# 0.652 (0.001) with: {'max_depth': 4, 'n_estimators': 10}
# 0.653 (0.001) with: {'max_depth': 4, 'n_estimators': 100}
# 0.653 (0.001) with: {'max_depth': 4, 'n_estimators': 1000}
# 0.657 (0.001) with: {'max_depth': 5, 'n_estimators': 10}
# 0.659 (0.002) with: {'max_depth': 5, 'n_estimators': 100}
# ...

# %%
grid_search_forest.best_params_
# Out:
# {'max_depth': 5, 'n_estimators': 1000}

# %%
grid_search_forest.best_score_
# Out:
# 0.6585573973336504

# %%
Y_pred_rf_grid=grid_search_forest.predict(X_test_std)

# %%
r2_score(Y_test,Y_pred_rf_grid)
# Out:
# 0.653328245399323

# %%
import joblib

# %%
joblib.dump(grid_search_forest,r'C:\Users\hp\Desktop\python file\Bigmart sale\Models\random_forest_grid.sav')
# Out:
# ['C:\\Users\\hp\\Desktop\\python file\\Bigmart sale\\Models\\random_forest_grid.sav']

# %%
model=joblib.load(r'C:\Users\hp\Desktop\python file\Bigmart sale\Models\random_forest_grid.sav')
